# %% [markdown]
# Name: Akshata Bheemasamudra Mallikarjunappa
#
# Student ID: 23164204

# %% [markdown]
# TASK 1a:

# %%
import pandas as pd

# %%
# !wget https://norvig.com/ngrams/count_1w.txt
unigrams_df = pd.read_csv('count_1w.txt' , delimiter = '\t', header = None, names = ['unigram','count'])
unigrams_df.head()
# Out:
# --2023-10-27 13:25:33--  https://norvig.com/ngrams/count_1w.txt
# Resolving norvig.com (norvig.com)... 158.106.138.13
# Connecting to norvig.com (norvig.com)|158.106.138.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4956241 (4.7M) [text/plain]
# Saving to: ‘count_1w.txt.6’
#
# count_1w.txt.6      100%[===================>]   4.73M  30.1MB/s    in 0.2s
#
# 2023-10-27 13:25:33 (30.1 MB/s) - ‘count_1w.txt.6’ saved [4956241/4956241]
#   unigram        count
# 0     the  23135851162
# 1      of  13151942776
# 2     and  12997637966
# 3      to  12136980858
# 4       a   9081174698

# %%
# !wget https://norvig.com/ngrams/count_2w.txt
bigrams_df = pd.read_csv('count_2w.txt' , delimiter = '\t', header = None, names = ['bigram', 'count'])
bigrams_df.head()
# Out:
# --2023-10-27 13:25:37--  https://norvig.com/ngrams/count_2w.txt
# Resolving norvig.com (norvig.com)... 158.106.138.13
# Connecting to norvig.com (norvig.com)|158.106.138.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5566017 (5.3M) [text/plain]
# Saving to: ‘count_2w.txt.2’
#
# count_2w.txt.2      100%[===================>]   5.31M  34.0MB/s    in 0.2s
#
# 2023-10-27 13:25:37 (34.0 MB/s) - ‘count_2w.txt.2’ saved [5566017/5566017]
#               bigram   count
# 0   0Uplink verified  523545
# 1             0km to  116103
# 2           1000s of  939476
# 3            100s of  539389
# 4  100th anniversary  158621

# %%
totalUnigrams = len(unigrams_df)  # index.sizeiloc[:,0]
totalBigrams = len(bigrams_df)     # .iloc[:,0]

# %%
print(f'Number of unigrams:{totalUnigrams} \t Number of Bigrams: {totalBigrams}')
display(unigrams_df.head(100),bigrams_df.head(100))
# Out:
# Number of unigrams:333333 	 Number of Bigrams: 286358
#     unigram        count
# 0       the  23135851162
# 1        of  13151942776
# 2       and  12997637966
# 3        to  12136980858
# 4         a   9081174698
# ..      ...          ...
# 95     like    520585287
# 96  service    519537222
# 97        x    508609523
# 98     than    502609275
# 99     find    502043038
#
# [100 rows x 2 columns]
#                bigram   count
# 0    0Uplink verified  523545
# 1              0km to  116103
# 2            1000s of  939476
# 3             100s of  539389
# 4   100th anniversary  158621
# ..                ...     ...
# 95            24th of  327460
# 96   25th anniversary  261023
# 97            25th of  397735
# 98            26th of  271707
# 99            27th of  276619
#
# [100 rows x 2 columns]

# %% [markdown]
# Task 1b:

# %%
# def probability(sentence):
#  sentence_probability = 1

unigrams = []
for word in range(len(sentence)):
 unigrams.append((sentence[word]))     #if word not in unique_words:     #unique_words.append(word)
print(unigrams)

unigrams = list(zip(sentence, sentence[1:]))
print(unigrams)

count_uni = sentence.count(word)
print(count_uni)

bigrams = []
for word in range(len(sentence)-1):
 bigrams.append((sentence[word],sentence[word+1]))     #if word not in unique_words:    #unique_words.append(word)
print(bigrams)

count_bi = sentence.count(word)
print(count_bi)

bigrams = list(zip(sentence, sentence[1:]))
print(bigrams)



######

words = sentence.split()
for word in words:
        if word in sentence:
            word_probability = unigrams[word] / sum(unigram.values())
        else:
           word_probability =
# Out:
# ['i', 'love', 'you']
# [('i', 'love'), ('love', 'you')]
# 0
# [('i', 'love'), ('love', 'you')]
# 0
# [('i', 'love'), ('love', 'you')]

# %%
count = 0
    for word in sentence:
      if word in totalUnigrams:
        count += 1
        word_probability = count/totalUnigrams
   	return sentenceProbability
probability("i love you")>probability('i hate you')

sentence = ['i','love','you']
probability(sentence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3655c0b66fec> in <cell line: 2>()
#       1 sentence = ['i','love','you']
# ----> 2 probability(sentence)
#
# <ipython-input-35-8ce2015b98da> in probability(sentence)
#       4
#       5  for word in sentence:
# ----> 6   if word in totalUnigrams:
#       7     word_probability = totalUnigrams[word] / sum(totalUnigrams.values())
#       8   else:
#
# TypeError: argument of type 'int' is not iterable

# %%
words = ['i' ,'love', 'you']


# for word in sentence:
#  if word in totalUnigrams:
#   word_probability = word / totalUnigrams
# print(word_probability)
